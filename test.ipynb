# %%
from transformers import AutoProcessor, VisionEncoderDecoderModel
import requests
from PIL import Image
import torch

processor = AutoProcessor.from_pretrained("DunnBC22/trocr-base-handwritten-OCR-handwriting_recognition_v2")
model = VisionEncoderDecoderModel.from_pretrained("DunnBC22/trocr-base-handwritten-OCR-handwriting_recognition_v2")

# load image from the IAM dataset
url = "https://github.com/C0D3-BR3AK3R/Easter2-OCR-LearnAI/blob/3f88bc22c3203ee3f4c4750b3368a6e6f07b2e71/test-data/img2.png"
image = Image.open(requests.get(url, stream=True).raw).convert("RGB")

# training
model.config.decoder_start_token_id = processor.tokenizer.eos_token_id
model.config.pad_token_id = processor.tokenizer.pad_token_id
model.config.vocab_size = model.config.decoder.vocab_size

pixel_values = processor(image, return_tensors="pt").pixel_values
text = "hello world"
labels = processor.tokenizer(text, return_tensors="pt").input_ids
outputs = model(pixel_values=pixel_values, labels=labels)
loss = outputs.loss

# inference (generation)
generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(
    generated_ids, skip_special_tokens=True)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 6
#       3 from PIL import Image
#       4 import torch
# ----> 6 processor = AutoProcessor.from_pretrained("DunnBC22/trocr-base-handwritten-OCR-handwriting_recognition_v2")
#       7 model = VisionEncoderDecoderModel.from_pretrained("DunnBC22/trocr-base-handwritten-OCR-handwriting_recognition_v2")
#       9 # load image from the IAM dataset
#
# File d:\Github\Deep-Learning-Basics\LangChains\Zephyr-7B-beta-RAG-Demo\zephyr\Lib\site-packages\transformers\models\auto\processing_auto.py:292, in AutoProcessor.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     288     return processor_class.from_pretrained(
#     289         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     290     )
#     291 elif processor_class is not None:
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-to-text", model="microsoft/trocr-base-handwritten")
pipe("test-data\img2.png")
# Out:
# WARNING:tensorflow:From d:\Github\Deep-Learning-Basics\OCR\Easter2-OCR-LearnAI\OCR-env\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From d:\Github\Deep-Learning-Basics\OCR\Easter2-OCR-LearnAI\OCR-env\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Use a pipeline as a high-level helper
#       2 from transformers import pipeline
# ----> 4 pipe = pipeline("image-to-text", model="microsoft/trocr-base-handwritten")
#       5 pipe("test-data\img2.png")
#
# ...
